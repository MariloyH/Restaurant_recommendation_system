# %% [markdown]
# ## Cleaning the yelp restaurants data

# %%
import pandas as pd
from pathlib import Path

# %%
#Read the csv file
resturants_df = pd.read_csv("Restaurants_reviews.csv")
resturants_df.head()
# Out:
#                        ID          Name  \
# 0  VdxJdMX53XZYNZvZlr96HA      LaoTable
# 1  tiSDprSVuesljC8b0aS64A  Wolfes Lunch
# 2  vu6PlPyKptsT6oEq50qOzA      Delarosa
# 3  VdxJdMX53XZYNZvZlr96HA      LaoTable
# 4  tiSDprSVuesljC8b0aS64A  Wolfes Lunch
#
#                                                Image  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/5UkRKN...
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/_OaI-p...
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/UPdC4G...
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/5UkRKN...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/_OaI-p...
#
#                                                  Url  Review count  Category  \
# 0  https://www.yelp.com/biz/laotable-san-francisc...          1296   Laotian
# 1  https://www.yelp.com/biz/wolfes-lunch-san-fran...           127  Japanese
# 2  https://www.yelp.com/biz/delarosa-san-francisc...          1494     Pizza
# 3  https://www.yelp.com/biz/laotable-san-francisc...          1296   Laotian
# ...

# %%
cleaned_restaurantes_df = resturants_df.drop_duplicates()

# %%
cleaned_restaurantes_df.to_csv('Cleaned_Restaurants_reviews.csv',index=False,header=True)
