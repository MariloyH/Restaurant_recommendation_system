# %%
# https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ## Using the yelp API to get restaurant data from San Francisco

# %%
#Import the required dependencies
import requests
import pandas as pd
import json
from urllib.parse import urlparse

#Import the API Key
from config import yelp_key

# %%
#Starting the URL for yelp API call
url = "https://api.yelp.com/v3/businesses/search"

#Define the header
headers = {
    'Authorization': 'Bearer %s' %yelp_key
}

# %%
#Define parameters for our query
parameters = {'location': 'San Franciso',
              'term':'food',
              'limit':50,
              'radius':40000,
              'offset':150
              }

# %%
#Make a request to the API
response = requests.get(url= url, params= parameters, headers= headers)
business_data = response.json()

# %%
#Create a list to store the data
complete_business_data = []

for business in business_data['businesses']:
    try:
        business_id = business['id']
        business_name = business['name']
        business_image = business['image_url']
        business_url_yelp = business['url']
        business_review_count = business['review_count']
        business_category = business['categories'][0]['title']
        business_rating = business['rating']
        business_price = business['price']
        business_lat = business['coordinates']['latitude']
        business_lng = business['coordinates']['longitude']
        business_address = business['location']['address1']
        business_city =  business['location']['city']
        business_state =  business['location']['state']
        business_country =  business['location']['country']
        business_phone = business['display_phone']
        
        complete_business_data.append({ 'ID': business_id,
                                       'Name':business_name,
                                      'Image':business_image,
                                      'Url':business_url_yelp,
                                       'Review count': business_review_count,
                                      'Category':business_category,
                                       'Rating': business_rating,
                                      'Price':business_price,
                                      'Latitude':business_lat,
                                      'Longitude':business_lng,
                                      'Address':business_address,
                                      'City':business_city,
                                       'State': business_state,
                                       'Country':business_country,
                                      'Phone':business_phone})
    except:
        print('This restaurant has missing information. Skipping...')
        pass
    
print("Data retrieval complete")
# Out:
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# This restaurant has missing information. Skipping...
# Data retrieval complete

# %%
#Retrieve the ID data for the restaurantes and then request the reviews with that ID

for dict in complete_business_data:
    dict['Review'] = []
    res_url = dict['Url']
    res_id = dict['ID']
    endpoint = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(res_id)
    response = requests.get(url= endpoint, headers= headers)
    business_reviews = response.json() #https://www.yelp-support.com/article/How-is-the-order-of-reviews-determined?}
    
    for review in business_reviews['reviews']:
            review_text = review['text']
            review_url = review['url']
            parse_res_url = urlparse(res_url)
            parse_rev_url = urlparse(review_url)
    
            #Compare URL from restaurants and reviews to pair them up
            if parse_res_url[2] == parse_rev_url[2]:
                dict['Review'].append(review_text)

# %%
#Check if the reviews were added correctly
complete_business_data
# Out:
# [{'ID': '9nltvO9__dkyRIT17D5TqQ',
#   'Name': 'Palm House',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/WEhiaYvvbCOpoGPH6rybtQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/palm-house-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1127,
#   'Category': 'Caribbean',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.797772,
#   'Longitude': -122.432887,
#   'Address': '2032 Union St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 749-9959',
#   'Review': ['One of my favorite places in the city. During the day, the place is a nice restaurant. Their food portion is big. I love the Cubano and spiced fries. Their...',
#    'We came here for a birthday party and rented the sun room at the entrance of the building. The minimum was $550 to book the place. We ordered several apps...',
#    'I went to Palm House today and sat at the bar. My friend and I got drinks and closed out. I live a block away. After I finish my drink at the bar with my...']},
#  {'ID': '5iZp3XBPOUTIqQY7vGAfVA',
#   'Name': 'Hotline',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/VO8rMtH4In-1uNV8VoS3NQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/hotline-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 29,
#   'Category': 'Korean',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.74203,
#   'Longitude': -122.50446,
#   'Address': '3560 Taraval St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 702-6301',
#   'Review': ['So I thought this was going to be a fast casual steam table joint.  Turned out you order at the counter and your food is made-to-order, which is fine by me...',
#    'Fans of Korean-Chinese food, we stopped by Hotline for a bite. Wow, did Hotline deliver with family-sized portions, perfect for sharing!\n\nWe ordered...',
#    'I came here for dinner with a friend yesterday and was overall impressed! \n\nI tried their one entree + one side combo (was a little sad they got rid of...']},
#  {'ID': 'XhJ6ZYagcWNHpJ1H1KvNlQ',
#   'Name': 'a Mano',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/ezG_zJwov2QNZwyK14EkwA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/a-mano-san-francisco-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1322,
#   'Category': 'Italian',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.776963880538,
#   'Longitude': -122.423868469312,
#   'Address': '450 Hayes St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 506-7401',
#   'Review': ["Our bartender was lovely. I don't recall his name but he had glasses and was serving us Tuesday night. Just great service and a great experience.",
#    "After running the San Francisco Marathon, I was craving a pizza.\n\nIt's pretty hard to get lunch foods delivered early in the day, but a Mano was on point! I...",
#    'Always busy, and for good reason! a Mano is cute, tasty, and quite affordable by SF standards. We arrived on a Friday night at 7:30 after being on the Yelp...']},
#  {'ID': 'YN01xIvPUgJeQer8EWgjyQ',
#   'Name': 'Sol Food Mill Valley',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/2uqHd9jeg0YrGdI2WE6W4Q/o.jpg',
#   'Url': 'https://www.yelp.com/biz/sol-food-mill-valley-mill-valley?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 985,
#   'Category': 'Latin American',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.89787,
#   'Longitude': -122.53555,
#   'Address': '401 Miller Ave',
#   'City': 'Mill Valley',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 380-1986',
#   'Review': ['First time coming to the Mill Valley location. It is take out only. I had seen a review that there was outdoor seating, but there were no tables or chairs...',
#    'After an epic Dipsea hike or any hike in Marin calls for amazing food to reward yourself with. Sol Food is an amazing choice. For this location, the...',
#    'The Cubano at this place is awesome!!!\n\nAlso, the plantains &fries are solid\n\nTry it out']},
#  {'ID': 'rdh_2_fXo5BeqYl_9OGZsA',
#   'Name': 'Saap Ver Authentic Thai Cuisine',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/YK8pR_x3lfV4PFcNqQn32g/o.jpg',
#   'Url': 'https://www.yelp.com/biz/saap-ver-authentic-thai-cuisine-san-francisco-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 608,
#   'Category': 'Thai',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.7698933,
#   'Longitude': -122.4045964,
#   'Address': '88 Division St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 255-8188',
#   'Review': ['Food tastes good but i consistently get food poisoning after coming here. Is it just me?',
#    'Full of flavors Thai foods and services was okay. \nI came here on Monday night for dinner around 6PM. The restaurant looks busy as this was my first time...',
#    "The best raw shrimp in town. \nIf you are going to order anytime make sure it's the shrimp. The atmosphere was very lively and the manager comes over to each..."]},
#  {'ID': 'cP4hJdL5MiRyHEAbM0KO_g',
#   'Name': 'Teahouse',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/cjxmApq3fRPUBZ9gSdW0BA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/teahouse-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 39,
#   'Category': 'Coffee & Tea',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.7703173336049,
#   'Longitude': -122.469726414681,
#   'Address': '75 Hagiwara Tea Garden Dr',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '',
#   'Review': ["What an absolute delight!\nThe Teahouse in the Japanese Tea Garden was the highlight of my visit there. \n\nIt's right in the middle of the tea garden and is...",
#    "My boyfriend and I decided to spend this past Sunday at the Golden Gate Park. We stopped by the Japanese Tea Garden first as we've been meaning to go for a...",
#    "Nice tea house that sells a variety of good Japanese tea and snacks.  It's a good place to take a break and enjoy the beautiful surroundings of the tea..."]},
#  {'ID': 'w3mpnxz64nU8VwHDLz3S6g',
#   'Name': 'Breadbelly',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/XNTsE9uUBUsWOsTuyGRvng/o.jpg',
#   'Url': 'https://www.yelp.com/biz/breadbelly-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 392,
#   'Category': 'Bakeries',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.78275,
#   'Longitude': -122.47439,
#   'Address': '1408 Clement St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 349-0969',
#   'Review': ['Honestly fantastic. Everything we had here was *very* good, despite the (eye poppingly) high prices (for a bakery).\n\nThe shrimp sandwich was totally worth...',
#    'We went around 11am on a Sunday and had to wait in a decent line. They have a cute outdoor seating area and that was packed, but luckily a seat was open...',
#    'I never believed in a love worth changing everything about yourself they always tell you about. At least not until today.\n\nIt was one of those usual days of...']},
#  {'ID': 'MNhRp6GhBiwCgGycyI6Mdw',
#   'Name': 'Cielito Lindo',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/nAZ-dTZMqpfar2OEslQKNQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/cielito-lindo-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 237,
#   'Category': 'Mexican',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.7759231,
#   'Longitude': -122.4957889,
#   'Address': '3450 Balboa St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 742-0959',
#   'Review': ['Birria has taken the West Coast foodie scene by storm. One place in which you can find a quality rendition of these stewed meats is here at Cielito Lindo,...',
#    'I really like this place but last time and it was my favorite also. However I found a cigarette between the burrito and the aluminum foil.\nWhen I called to...',
#    'A quickly visit to San Francisco to ride the Golden Gate Bridge. Ridding the bridge got us hungry and stomped upon this restaurant. \n\nThe inside is simple...']},
#  {'ID': 'oXjd7i1LAgeAWcMup0N1zg',
#   'Name': 'Aburaya Japanese Fried Chicken',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/Wi8T9wybSihGmtOpv-YpHg/o.jpg',
#   'Url': 'https://www.yelp.com/biz/aburaya-japanese-fried-chicken-oakland-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 853,
#   'Category': 'Izakaya',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.8059903,
#   'Longitude': -122.2676427,
#   'Address': '362 17th St',
#   'City': 'Oakland',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(510) 502-7743',
#   'Review': ['Always be consistent and really good!\n\nWe get the 8 piece with the rice and salad for $2.00 extra and ask for the garlic and bbq type chicken.\nThis feeds...',
#    "Did you get to Hawai'i and then realize that you couldn't eat local food cuz you're gluten intolerant and everything has soy sauce?!\n\nGluten free Loco Moco...",
#    "This review is just for the tofu rice bowl, so if you want chicken this is not the one read. I've tried the bbq sauce but the garlic miso rub is where it's..."]},
#  {'ID': 'jLjbntnlmxsX8gsOxZVUcQ',
#   'Name': 'RAW Sugar Factory',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/NJfAaVl6cido95mCLYLpzg/o.jpg',
#   'Url': 'https://www.yelp.com/biz/raw-sugar-factory-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 723,
#   'Category': 'Breakfast & Brunch',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.76444,
#   'Longitude': -122.42157,
#   'Address': '525 Valencia St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 872-9608',
#   'Review': ['Not your typical RAW Sugar Factory, this place has a LOT to offer for brunch. Everything from kimchi fries to matcha french toast to chicken and waffles! We...',
#    'HAD A RESERVATION ON MY BDAY 2:30PM TODAY (they knew about it because the lady attempted to call me but DID NOT leave a voicemail) BUT THEY CLOSED EARLY &...',
#    'It\'s places like this that makes me swear off trying new restaurants in SF. Trying to be fancy with "Asian fusion" but failing horribly. For starters,...']},
#  {'ID': 'IJk76B-pTta_klpAZcpQdA',
#   'Name': "Lou's Cafe",
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/zjE21goq1XUXE3iFzlLSuA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/lous-cafe-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1746,
#   'Category': 'Coffee & Tea',
#   'Rating': 4.5,
#   'Price': '$',
#   'Latitude': 37.78045,
#   'Longitude': -122.47329246476227,
#   'Address': '5017 Geary Blvd',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 379-4429',
#   'Review': ["Lou's Cafe, I like you!\nThe shop feels welcoming, the staff are nice, the prices are very reasonable.\nSimple, no gimmick sandwiches.\nI like this location...",
#    'I went there today in person and I was told the order is 15 min then after 20 find out they are working on a huge catering order the Tian place from last...',
#    "maybe it's because it's a holiday weekend or maybe it's because it's busy but i ordered on yelp and it notified me that my sandwiches were ready at 1:30pm...."]},
#  {'ID': '_ZysfO74zEDOooCktoEBVw',
#   'Name': 'Hing Lung Company aka Go Duck Yourself',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/n1NTXTnZDqFddt75WP2jvQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/hing-lung-company-aka-go-duck-yourself-san-francisco-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 169,
#   'Category': 'Barbeque',
#   'Rating': 4.5,
#   'Price': '$',
#   'Latitude': 37.797410219936,
#   'Longitude': -122.408709611199,
#   'Address': '1261 Stockton St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '',
#   'Review': ["I am so in  with this Food and Sauces.. Ordered Uber Eats over to The Fillmore, after craving something different. Shout Out to my City's Asian Communities...",
#    'Best duck and best service !! We arrived from Miami just to eat here and when we got here we got the last duck!! \nThe owner Simon was super kind and...',
#    'Was searching through YELP for a good duck recommendation. Found this place near by where we were going to stop at to pick up dim sum. \n\nRight when we got...']},
#  {'ID': 'kFgjHGp-cTUK5uPaSJOORA',
#   'Name': 'Souvla',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gg_ynaIhzIdfTxKXTQmfUA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/souvla-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1601,
#   'Category': 'Greek',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.77643,
#   'Longitude': -122.425,
#   'Address': '517 Hayes St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 400-5458',
#   'Review': ["If you're ever in San Fransisco, then you have to try this place!\n\nI ordered the chicken salad which was filled with flavor. They gave a generous portion of...",
#    "FYI: They don't have any trash cans laying out and about (at least when we went) so if you want to throw away your finished yogurt cup, ask the staff member...",
#    "I was expecting a lot more honestly, especially since the chicken on the rotisserie looked really good and the pictures on yelp looked great. \n\nHere's what..."]},
#  {'ID': 'UuFovQRilF7fCmokiiW05w',
#   'Name': 'The Sandwich Shop',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/-T7b2F2ay7FsOpjwDdBl-Q/o.jpg',
#   'Url': 'https://www.yelp.com/biz/the-sandwich-shop-san-francisco-3?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 117,
#   'Category': 'Sandwiches',
#   'Rating': 4.5,
#   'Price': '$',
#   'Latitude': 37.763503,
#   'Longitude': -122.388593,
#   'Address': '2071 3rd St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 934-0756',
#   'Review': ["3/18/22\n\nI love this sandwich shop!  I didn't bring lunch that day and had heard from my coworkers that The Sandwich Shop sells great sandwiches.  It's...",
#    "If you're looking for a filling sandwich definitely do not recommend the Reuben. I was not expecting to pay $20+ (not including delivery) for a sandwich...",
#    'A cute clean open sandwich place in Dogpatch. I built a sandwich for $12, which ended up being large enough for 2 small meals. The portion of meat was...']},
#  {'ID': 'iMyA8ZgPZrQjSzhS_T-z9Q',
#   'Name': 'Banh Mi Love',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/bcox_GbeZ5T5oLzgeJ7MHw/o.jpg',
#   'Url': 'https://www.yelp.com/biz/banh-mi-love-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 75,
#   'Category': 'Vietnamese',
#   'Rating': 4.5,
#   'Price': '$',
#   'Latitude': 37.7301499,
#   'Longitude': -122.4764287,
#   'Address': '597 Buckingham Way',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 941-7814',
#   'Review': ['After a shift volunteering with the SF Food Bank pop nearby at the YMCA, I was hung-gray!  Thankfully I remembered that I needed to stop by Banh Mi Love for...',
#    'I really, really, really wanted to love this place. Like I read the reviews the night before and was so excited to try it. I found it inside the business...',
#    "Holy cow, where's that bonus star??! Cuz Banh Mi Love deserves 6 stars and they have my eternal love, forever and always! I've been skeptical about coming..."]},
#  {'ID': 'q1Mv7oQSOorl4a9zbtl-rQ',
#   'Name': 'Marugame Udon',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/BQxRHkBkV1yCRgufMMPUsw/o.jpg',
#   'Url': 'https://www.yelp.com/biz/marugame-udon-san-francisco-4?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 2150,
#   'Category': 'Japanese',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.727494,
#   'Longitude': -122.476531,
#   'Address': '3251 20th Ave',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 680-1280',
#   'Review': ['I came around 6:45 PM on a Friday, and the wait was about 15 minutes. Once I reached the counter where you start ordering, I got my food fairly quickly....',
#    "I remember when this spot first opened and there would long lines \n that would twirl around outside. Present day, lines aren't as lone (thankfully). I came...",
#    '"If you pull it, you better use it." - Black Rain\n\nI\'ve been to Marugame Udon dozens of times, but this was when I lived in Honolulu with my given parts to...']},
#  {'ID': '3sGEIoyXkMmc1YX1TYkSMg',
#   'Name': 'Pancake Boy',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/EJ9p6FvfqvBIXSpRqhYa0Q/o.jpg',
#   'Url': 'https://www.yelp.com/biz/pancake-boy-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1119,
#   'Category': 'Breakfast & Brunch',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.75124,
#   'Longitude': -122.43213,
#   'Address': '4007 24th St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 647-7037',
#   'Review': ['Excellent breakfast! Efficient friendly service. Large portions. Would definitely return!',
#    'Great food and great service.\nStopped in here for brunch today and was pleasantly surprised.\nStaff was super friendly and helpful.\nTried the Lobster...',
#    'Pancakes are delicious and filling. Super fluffy!\n\nCorned beef hash was OK, you get soft potatoes with it but they definitely give you 2/3 potato and 1/3...']},
#  {'ID': 'bUr4iq2mKKiBOu2HKynylg',
#   'Name': 'HRD',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/G05B7mvYPHBpGu1wP1NK_Q/o.jpg',
#   'Url': 'https://www.yelp.com/biz/hrd-san-francisco-4?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 2524,
#   'Category': 'Asian Fusion',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.7811065758548,
#   'Longitude': -122.395329724426,
#   'Address': '521A 3rd St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 543-2355',
#   'Review': ['This place is solid for Asian fusion food! They have Asian inspired proteins including panko-crusted shrimp, wild cod katsu, tuna poke, and bulgogi beef....',
#    'We to HRD for a quick lunch, after looking at the different reviews and getting excited for a unique burrito! Once there you basically order and get a...',
#    'Great fusion cuisine coffee shop!!! I just love it.\nWhat I always come for is the Kimchi Burrito, Korean/Mexican meal on the go, simply genius.\nTotally...']},
#  {'ID': 'KjbJ8iQJZJybaB4g5W1A-Q',
#   'Name': 'Beyond Cafe',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/hBgVz7O2uJvDSRuM8tY4IQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/beyond-cafe-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 123,
#   'Category': 'Chinese',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.77241,
#   'Longitude': -122.4075,
#   'Address': '1010 Bryant St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 565-7395',
#   'Review': ['Omg this place is tasty !! \n\nWe ordered the soy sauce chicken, wonton lo mein noodles. And Beef stew lo mein wow \n\nGlad I found this spot! \n\nOver all 5 star...',
#    'Great noodles! \nA gem in the city here!\nRecommended highly. Definitely will come back the wontons are so delicious!',
#    'this review has to do with the customer service I experienced today. it has nothing to do with the food.\n\nI was stuck in traffic waiting to get on the...']},
#  {'ID': 'IZDjh1y4m6d6wnG0gHZnQg',
#   'Name': 'Chef Reina',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/0B13eDh9Phz6VM3X5VLSGA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/chef-reina-brisbane?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 66,
#   'Category': 'Filipino',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.68408259624203,
#   'Longitude': -122.4026486606288,
#   'Address': '33 Visitacion Ave',
#   'City': 'Brisbane',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(650) 989-8606',
#   'Review': ["Must order: Laing! But it's seasonal so may not be available every time I go. So sad.\n\nThe spam musubi feel like it's not very worth it as a single item....",
#    'I ordered tocino and lechon kawali. Its very hard to imitate lechon kuwali and tocino. For what it is and its "vegan" filipino food. Its pretty good but...',
#    'So so good! Good portions, quick pickup, and super friendly staff. Danielle took our order and checked us out and was so sweet & super friendly. We will be...']},
#  {'ID': '7dHj1XDVA_7AYXTfp5i-BQ',
#   'Name': 'MOMO noodle',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/PLMiHaE7EZgSvPetGq5A4Q/o.jpg',
#   'Url': 'https://www.yelp.com/biz/momo-noodle-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 99,
#   'Category': 'Noodles',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.791053771972656,
#   'Longitude': -122.40193176269531,
#   'Address': None,
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(408) 800-6819',
#   'Review': ['Brought a couple of friends to experience Spark Social (food truck location) :)\n\nFirst Impression: Spark Social vibes are uncomparable - lots of really...',
#    'WHEN: Sunday @ 3pm\n\nLocated at Spark Social in mission bay. Momo noodle is a food truck, you use the iPad for ordering, then it prints out a number for you...',
#    'Easily one of the best noodle trucks in the peninsula. i ordered the Spicy Pork and yes it is more than enough to fill. I suggest drinking water as it is...']},
#  {'ID': 'K24TuqugeeJVkaFkS166BA',
#   'Name': 'Yuanbao Jiaozi',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/KcHmgBG-18MWZeyScOl85g/o.jpg',
#   'Url': 'https://www.yelp.com/biz/yuanbao-jiaozi-san-francisco-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 468,
#   'Category': 'Chinese',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.76356,
#   'Longitude': -122.48067,
#   'Address': '2110 Irving St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 702-6506',
#   'Review': ["So, I've been eating here a lot. Employees are super friendly, kind, and patient. I come here to often that I'm basically a regular. Me, my mom, and my...",
#    "First time here and O-M-G I can't recommend this enough. Great value and delicious food.\n\nWe came on a Sunday during lunch and there was about a ~10 minute...",
#    "This place is such a hidden gem! Definitely recommend the Shrimp & Zucchini Dumplings and the Shrimp, Chive, & Egg Dumplings. They're so warm, tender, and..."]},
#  {'ID': '4EP1xjPpLFa2Cn_tZGHlYw',
#   'Name': "Amy's Drive Thru",
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/DyicDMv_vCGOUZhTF-qlnA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/amys-drive-thru-corte-madera-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 198,
#   'Category': 'Burgers',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.924444706054615,
#   'Longitude': -122.51309536095121,
#   'Address': '5839 Paradise Dr',
#   'City': 'Corte Madera',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 737-6055',
#   'Review': ["Didn't realize amy's is the same as the brand you can find in the grocery store frozen sections!\n\nI fell in love with this place so fast since they have...",
#    "taxes vegans\n\nnon dairy milkshake $6.99 and cruelty shake is $5 99\n\nnice to have this option but do better.\n\nlet the ' vegitarians' subsidize the vegans.....",
#    "I had this impression of Amy's Drive Thru serving the same type of mediocre frozen food you can find in the grocery store. Haha I was wrong. \n\nThe..."]},
#  {'ID': '4-ra3RxOy1PpvnaK49dy8w',
#   'Name': 'Eight AM',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/8TFLuxxAOIkJRiVp5cQWBQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/eight-am-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1551,
#   'Category': 'American (New)',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.80627591985745,
#   'Longitude': -122.41919541296622,
#   'Address': '1323 Columbus Ave',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 292-4888',
#   'Review': ['We are here multiple times during our SF trip--the food was amazing and service very attentive. Will definitely be eating here on our next trip.',
#    "We are locals but live about 2 hours away now so decided to play 'tourist' \nChecked online for places to eat near our hotel and this place popped up....",
#    'Great food! Excellent quality! There were 6 of us and everyone left extremely satisfied. We enjoyed the avocado toast, a few bagel fix ups, a frittata, and...']},
#  {'ID': 'wxzx3duu1c0CcomzEOvfOQ',
#   'Name': 'The Front Porch',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/0fmMVyqSKOMIqtkQksUTUQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/the-front-porch-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 3061,
#   'Category': 'Southern',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.7438,
#   'Longitude': -122.422035,
#   'Address': '65 29th St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 695-7800',
#   'Review': ["Just such solidly good food. Also just amazingly friendly service. A note about that: we've kind of become accustomed to crap and rude service in sf and so...",
#    'Came for dinner after finding a last-minute reservation, fun atmosphere and service was very friendly! The space itself it not very large, but they have...',
#    'Atmosphere here is a whole vibe for sure! Customer service is also too notch!\n\nFor the food. We were given the Macaroni and cheese as a gift and I have to...']},
#  {'ID': 'ZdKUKq7A94x9cEobARf2cA',
#   'Name': "Breakfast at Tiffany's",
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/YjZYF7Vz6JbsZYfwIt5WPw/o.jpg',
#   'Url': 'https://www.yelp.com/biz/breakfast-at-tiffanys-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1033,
#   'Category': 'Diners',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.7304538339376,
#   'Longitude': -122.40473203361,
#   'Address': '2499 San Bruno Ave',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 468-8805',
#   'Review': ["Best thing about this place is the fresh squeezed orange juice, always really cool and sweet! \n\nI order the Tiffany's all meat tater tot skillet almost...",
#    'Delicious and such a fun atmosphere!\nOur waitress was so attentive and sweet even sitting at the bar. \nWe both loved it!',
#    'The Trio Benedict was delicious, but the hash browns were bland and not crispy. I recommend ordering tater tots instead.\n\nThey also forgot about our...']},
#  {'ID': 'kUxtjTa2vCSWQvr00YwxQw',
#   'Name': 'Kazan',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/YFjJ96YGoB-U2j0GFpZ7UQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/kazan-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 531,
#   'Category': 'Japanese',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.752694,
#   'Longitude': -122.408469,
#   'Address': '2809 24th St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 282-2001',
#   'Review': ["Best Sushi spot in all of SF for value, taste and quality. \n\nI've been here 3x and always order the sashimi omakase because it's just the best in town....",
#    'Was working in San Fran and before my scout I hit a what seems to be a local whole in the wall place! KAZAN is definitely a very nice place to come dine in!...',
#    'Food: 3/5\nService: 3.5/5\nAmbiance: 3.5/5\nOverall: Food was pretty standard fare in my opinion.\n\nThe extended review...\n\nFood:\n\nBeef Gyoza - 3/5 - A good...']},
#  {'ID': 'a-Lf60V3BDdS27la95VQWA',
#   'Name': 'Hodala',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/aFrde5SlRjFVFqiFM8gxsg/o.jpg',
#   'Url': 'https://www.yelp.com/biz/hodala-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 633,
#   'Category': 'Taiwanese',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.7800054050483,
#   'Longitude': -122.481684274971,
#   'Address': '5801 Geary Blvd',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 702-9510',
#   'Review': ['I like this restaurant  I think their stuff are really nice \nThe food are so yummy \nReally good\nI like the fired chicken',
#    'Hodala Ratings: 4/5\n\nFood: 4/5 - I was searching for some comfort food after long travels, and Hodala caught my attention. I am always on the hunt for good...',
#    'Definitely a hole in the wall. This was my first time here and my favorite dish was the Taiwanese pork belly gua bao.\n\nThey have a large variety of drinks...']},
#  {'ID': '3tn9eZJhlhdSBwux440nSA',
#   'Name': 'Chome',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/lQvJugCqhIIiWlY0Aq-J5A/o.jpg',
#   'Url': 'https://www.yelp.com/biz/chome-san-francisco-3?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 144,
#   'Category': 'Izakaya',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.76209,
#   'Longitude': -122.41924,
#   'Address': '2193 Mission St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 757-0922',
#   'Review': ['Amazing place to sit back and have a good time with drinks and small bites! We went as a group and it took awhile to get a table but the wait was worth it....',
#    'Cozy, cute, hole in the wall spot in the mission serving delicious Japanese izakaya food with a modern twist. While it took a while to get seated after...',
#    'This place really is just lovely. The food was amazing, the service is very quick, and the staff were very nice!\n\nMy girlfriend and I came to Chome...']},
#  {'ID': 'xpxqr2WJRbLaBakdUrlfTw',
#   'Name': 'STIX',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/BPpfcpwcs4bHNo7IL5_t0w/o.jpg',
#   'Url': 'https://www.yelp.com/biz/stix-san-francisco-5?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 342,
#   'Category': 'Hot Dogs',
#   'Rating': 4.0,
#   'Price': '$',
#   'Latitude': 37.74258,
#   'Longitude': -122.48085,
#   'Address': '1353 Taraval St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 463-6577',
#   'Review': ["It taste so good, I recommend! It's super cheesy, hot and fresh. It was my first time trying it and it exceeded my expectations, the sugar coated around it...",
#    'This place can be busy when the local school let out,luckily I got mine just minutes before. I sat in my car devouring my first Korean dog watching a steady...',
#    "Light and fluffy batter, making for a crunchy bite each time!! So glad we decided to stop by for a quick snack. Although they don't currently offer indoor..."]},
#  {'ID': '25jFWHEbHmQbaTxaM_UfTg',
#   'Name': "Good Gai's",
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/26MSE7cdi4jDbFzthgGKvw/o.jpg',
#   'Url': 'https://www.yelp.com/biz/good-gais-san-francisco-3?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 41,
#   'Category': 'Chicken Shop',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.7419259154122,
#   'Longitude': -122.40365186384315,
#   'Address': '2723 Oakdale Ave',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 796-3906',
#   'Review': ["Good Gai's is a solid Khao Man Gai (Chicken and Rice) spot that opened up in Hawker Alley in the Bayview. So happy to see good eats popping up closer to...",
#    "Simply the best Hainan chicken rice in SF. And relatively affordable to boot!\n\nI'm also a big fan of the steamed baos, particularly the miso tofu.\n\nLove...",
#    'This might be the best spot for Karaage chicken in SF! You get so much for what you pay for, and the dipping sauces that came with the chicken were so good....']},
#  {'ID': 'ziDJD2-M38PUEmft4kJ8nQ',
#   'Name': 'SoMa StrEat Food Park',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/R2MiYujs1X4I8QiDTd3AbA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/soma-streat-food-park-san-francisco-4?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 878,
#   'Category': 'Food Trucks',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.76985,
#   'Longitude': -122.41175,
#   'Address': '428 11th St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '',
#   'Review': ['Great variety of food trucks and a great ambience.\nI totally recommend De La Calle food truck. Great Mexican street food!',
#    'I used to come to this food truck park multiple times a week as I lived nearby. I loved all the great trucks and would attend events and have game meetups...',
#    "Expensive, not too much options and very far from everything. Definitely not worth it. \nI got there around 3 hours before they closed and already doesn't..."]},
#  {'ID': 'NwqdohySKrDnK0RsAde9UA',
#   'Name': 'Hot Sauce and Panko',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/gqkZBrUjvBDkDUr3ByNO7Q/o.jpg',
#   'Url': 'https://www.yelp.com/biz/hot-sauce-and-panko-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1261,
#   'Category': 'Chicken Wings',
#   'Rating': 4.5,
#   'Price': '$',
#   'Latitude': 37.794505,
#   'Longitude': -122.417957,
#   'Address': '1468 Hyde St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 359-1908',
#   'Review': ["Who doesn't like crispy wings! Yumm this place is a hole in the wall and sooo good. Just FYI- They do not have any seating, it's a take out only. \n\nWe tried...",
#    "As a lover of all things chicken wings, I can't believe it's taken me this long to try Hot Sauce and Panko. People have always told me they got some the...",
#    "Stop reading if you don't like hole in the wall/diamonds in the rough.\n\nStop reading if you don't like perfectly balanced and seasoned fried chicken wings..."]},
#  {'ID': 'ey_UUXdDMUoO77QIF6SGaQ',
#   'Name': 'Mensho Tokyo SF',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/4L3t1-0-tI0h4CC_NgLoMA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/mensho-tokyo-sf-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 2553,
#   'Category': 'Ramen',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.78686,
#   'Longitude': -122.41439,
#   'Address': '672 Geary St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 800-8345',
#   'Review': ['As a pescatarian, I was never really impressed or satisfied by the ramen I had previously tried, which often lacked flavor and fullness. After just one...',
#    'Mensho Tokyo was worth the wait. My team waited in the line on the sidewalk for about an hour. The door was propped open and the glass wall illuminated...',
#    "I came here to give it another try. But I'm quite disappointed tbh.\n\nWe waited for about 20mins to get a table, so I was fine with that. But the QR code..."]},
#  {'ID': 'NiL32rwaK1AlFkD3vlaRtw',
#   'Name': 'Tokyo Fish Market',
#   'Image': 'https://s3-media4.fl.yelpcdn.com/bphoto/fx1uWjkLNOEkrMYXiZ65CQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/tokyo-fish-market-berkeley-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 865,
#   'Category': 'Seafood Markets',
#   'Rating': 4.5,
#   'Price': '$$',
#   'Latitude': 37.8814694826618,
#   'Longitude': -122.296665832383,
#   'Address': '1220 San Pablo Ave',
#   'City': 'Berkeley',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(510) 524-7243',
#   'Review': ['Honestly, this changed my whole understanding of what "good" fish is. I love having a simple baked salmon and thought to buy some here because I had heard...',
#    "I come here mostly for the sashimi-grade fish. I've also picked up different shellfish, caviar, and other miscellaneous items. The counter people are nice...",
#    "If you're into sashimi, this is the spot. They have fresh sashimi daily. I love their tuna belly, salmon, hamachi and fresh Wasabi  I've been here multiple..."]},
#  {'ID': '6LgVPqC6HFU_q0KrIW1B1Q',
#   'Name': 'Ben Tre Vietnamese Homestyle Cuisine',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z1_8uArjVHO49OBQ17iyXA/o.jpg',
#   'Url': 'https://www.yelp.com/biz/ben-tre-vietnamese-homestyle-cuisine-south-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1951,
#   'Category': 'Vietnamese',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.6557878294219,
#   'Longitude': -122.412228137255,
#   'Address': '398 Grand Ave',
#   'City': 'South San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(650) 952-2243',
#   'Review': ["According to my fiancé, their beef pho is the best he's ever had. They're flavorful and meaty. I had the papaya vermicelli salad with shrimp and white...",
#    "Listen. I go to a place 3 times before I review.\n\nSo,\n\nI've had Pho all around the Bay Area but Ben Tre is something special. I've been going here since...",
#    'Came here last Friday around 7:40 pm.\nWe waited about 20 mins to get seated. \nWe ordered garlic noodle with filet mignon plate and short ribs and chicken...']},
#  {'ID': '4KfQnlcSu4bbTqnvGdGptw',
#   'Name': 'Beretta',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/HKxMJ8q8fzOY76hy7ACIag/o.jpg',
#   'Url': 'https://www.yelp.com/biz/beretta-san-francisco?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 3975,
#   'Category': 'Italian',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.753869,
#   'Longitude': -122.420611,
#   'Address': '1199 Valencia St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 695-1199',
#   'Review': ["Beretta captures the best of two worlds: it's a down-to-earth, neighborhood restaurant mixed with all the best parts of a professional kitchen and staff....",
#    'Very good food, fresh and delicious \nGood service and good vibe i really like it, my way to see a quality in a food place is by the restaurant restrooms!...',
#    'This place can get packed for dinner so make sure you come early or make a reservation.\n\nWe got the tricolore salad and fried cauliflower for appetizers...']},
#  {'ID': '1IqqA8pcuCIWJtuKfHwU8g',
#   'Name': 'Nojo Ramen Tavern',
#   'Image': 'https://s3-media3.fl.yelpcdn.com/bphoto/f8jcPmO2OhZr9w11Bj2zeg/o.jpg',
#   'Url': 'https://www.yelp.com/biz/nojo-ramen-tavern-san-francisco-6?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 1066,
#   'Category': 'Ramen',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.77669,
#   'Longitude': -122.42151,
#   'Address': '231 Franklin St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 896-4587',
#   'Review': ['Really great food, friend recommended from out of state. The inside was a decent size with a couple booth seats, but the service speed and quality was where...',
#    'Nojo Ramen Tavern has a highly rated Ramen menu in San Francisco, and I came in to taste some of their newest dishes! Everything looked and smelled...',
#    "I usually only have one specific place in mind in the Bay when I'm craving ramen, but Nojo's signature Chicken Paitan Soy Sauce fulfilled this ramen itch I..."]},
#  {'ID': '5o24fe7v2Z0dgt3TCkZ1ww',
#   'Name': 'Milkbean',
#   'Image': 'https://s3-media1.fl.yelpcdn.com/bphoto/SsSI2kH4Yq68hcZJJmdnkQ/o.jpg',
#   'Url': 'https://www.yelp.com/biz/milkbean-san-francisco-4?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 290,
#   'Category': 'Cafes',
#   'Rating': 4.5,
#   'Price': '$',
#   'Latitude': 37.7871613,
#   'Longitude': -122.4162122,
#   'Address': '881 Post St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 866-8811',
#   'Review': ['came across this spot while on the go & i was pleasantly surprised! super sweet staff & my latte was perfection! cant wait to come back (:',
#    'Editing my review after I had one of their sandwiches and the service has been better! I keep coming back for their sandwiches now and their lavender latte...',
#    "Been here a few times already, but didn't write a review until now. Great sandwiches (huge!) and a cute spot which is unexpectedly nice."]},
#  {'ID': 'KwEekEeXIQtt_CZtp8LAOA',
#   'Name': 'Aracely Cafe',
#   'Image': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qbi_OwMIoiRCMYkDlsLtWg/o.jpg',
#   'Url': 'https://www.yelp.com/biz/aracely-cafe-san-francisco-2?adjust_creative=Sb39Q_neG8ncCfDxiJ2TWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Sb39Q_neG8ncCfDxiJ2TWw',
#   'Review count': 331,
#   'Category': 'American (New)',
#   'Rating': 4.0,
#   'Price': '$$',
#   'Latitude': 37.8278,
#   'Longitude': -122.37417,
#   'Address': '401 13th St',
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Country': 'US',
#   'Phone': '(415) 678-5724',
#   'Review': ["There is a freeway interchange on the east side of the Bay Bridge that i absolutely h-eight: the 80 meets both the 580 and the 880.  All these 8's were like...",
#    "I'm not sure why my experience is so different than so many other people's,  but it wasn't good. I'm from Dallas, Texas and I've had much better...",
#    'Enjoyed this small treasure island restaurant at the recommendation of a coworker. We sat outdoors in a nicely sunlit area and were quickly served by a very...']}]

# %%
#Store the data in a dataframe
restaurants_df = pd.DataFrame(complete_business_data)
restaurants_df.head(2)
# Out:
#                        ID        Name  \
# 0  9nltvO9__dkyRIT17D5TqQ  Palm House
# 1  5iZp3XBPOUTIqQY7vGAfVA     Hotline
#
#                                                Image  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/WEhiaY...
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/VO8rMt...
#
#                                                  Url  Review count   Category  \
# 0  https://www.yelp.com/biz/palm-house-san-franci...          1127  Caribbean
# 1  https://www.yelp.com/biz/hotline-san-francisco...            29     Korean
#
#    Rating Price   Latitude   Longitude          Address           City State  \
# 0     4.0    $$  37.797772 -122.432887    2032 Union St  San Francisco    CA
# 1     4.0    $$  37.742030 -122.504460  3560 Taraval St  San Francisco    CA
#
#   Country           Phone                                             Review
# 0      US  (415) 749-9959  [One of my favorite places in the city. During...
# 1      US  (415) 702-6301  [So I thought this was going to be a fast casu...

# %%
#Store the information in a CSV filke
restaurants_df.to_csv('Restaurants_reviews.csv',index=False,header=True)
